# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

import warnings
warnings.filterwarnings('ignore')

# %%
Accident  = pd.read_csv('datasets\\accident_data.csv')
Accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
Accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
#  13  Vehicle_Type             660679 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.6+ MB

# %%
Accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %% [markdown]
# <h1>Filling up Null Values</h1>

# %%
Accident['Latitude'] = Accident['Latitude'].fillna(Accident['Latitude'].mode()[0])

# %%
Accident['Longitude'] = Accident['Longitude'].fillna(Accident['Longitude'].mode()[0])

# %%
Accident['Urban_or_Rural_Area'] = Accident['Urban_or_Rural_Area'].fillna(Accident['Urban_or_Rural_Area'].mode()[0])

# %%
Accident['Road_Surface_Conditions'] = Accident['Road_Surface_Conditions'].fillna(Accident['Road_Surface_Conditions'].mode()[0])

# %%
Accident['Road_Type'] = Accident['Road_Type'].fillna('unknown')

# %%
Accident['Weather_Conditions'] = Accident['Weather_Conditions'].fillna('unaccounted')

# %%
Accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %% [markdown]
# <h1>Data Types</h1>

# %%
Accident['Accident_Severity'] = Accident['Accident_Severity'].astype('category')

# %%
Accident['Accident Date'] = pd.to_datetime(Accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
Accident['Light_Conditions'] = Accident['Light_Conditions'].astype('category')

# %%
Accident['District Area'] = Accident['District Area'].astype('category')

# %%
Accident['Road_Surface_Conditions'] = Accident['Road_Surface_Conditions'].astype('category')

# %%
Accident['Road_Type'] = Accident['Road_Type'].astype('category')

# %%
Accident['Urban_or_Rural_Area'] = Accident['Urban_or_Rural_Area'].astype('category')

# %%
Accident['Weather_Conditions'] = Accident['Weather_Conditions'].astype('category')

# %%
Accident['Vehicle_Type'] = Accident['Vehicle_Type'].astype('category')

# %%
Accident.dtypes
# Out:
# Index                              object
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                          float64
# Light_Conditions                 category
# District Area                    category
# Longitude                         float64
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# dtype: object

# %% [markdown]
# <h1>Extracting date information using pandas date time</h1>

# %%
Accident['Year'] = Accident['Accident Date'].dt.year
Accident['Month'] = Accident['Accident Date'].dt.month
Accident['Day'] = Accident['Accident Date'].dt.day
Accident['DayOfWeek'] = Accident['Accident Date'].dt.dayofweek #Monday=0, Sunday=6

# %% [markdown]
# <h3>Question:</h3>
# <h2>What is the distribution of accident severity levels in the dataset?</h2>

# %%
Accident['Accident_Severity'].value_counts(normalize=True)
# Out:
# Accident_Severity
# Slight     0.853366
# Serious    0.133525
# Fatal      0.013109
# Name: proportion, dtype: float64

# %%
plt.hist(Accident['Accident_Severity'], color='blue', alpha=0.7)
plt.title('Histogram of Data')
plt.xlabel('Accident severity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <h1>Severity by Year</h1>

# %%
Sy = Accident.groupby(['Year', 'Accident_Severity']).size().unstack(fill_value=0)
Sy
# Out:
# Accident_Severity  Fatal  Serious  Slight
# Year
# 2019.0              1116     9823   60928
# 2020.0               942     9346   59875
# 2021.0               823     8858   56491
# 2022.0               623     7266   48916

# %%
severityPYear = Sy.div(Sy.sum(axis=1), axis=0) * 100
severityPYear
# Out:
# Accident_Severity     Fatal    Serious     Slight
# Year
# 2019.0             1.552868  13.668304  84.778828
# 2020.0             1.342588  13.320411  85.337001
# 2021.0             1.243728  13.386327  85.369945
# 2022.0             1.096734  12.791128  86.112138

# %%
mostfreqSeverity = severityPYear.idxmax(axis=1)
mostfreqSeverity
# Out:
# Year
# 2019.0    Slight
# 2020.0    Slight
# 2021.0    Slight
# 2022.0    Slight
# dtype: category
# Categories (3, object): ['Fatal', 'Serious', 'Slight']

# %% [markdown]
# <h1>Insight1</h1>
# <h2>The most frequent accident severity level is Slight, representing approximately 85.3366%</h2>

# %% [markdown]
# <h3>Question:</h3>
# <h2>If the most frequent accident severity level is Slight, Does it change every year?</h2>

# %%
isSlightDominant = (mostfreqSeverity == 'Slight').all()
isSlightDominant
# Out:
# True

# %%
severityPYear.plot(kind='bar', stacked=True, figsize=(10,5))
plt.title('Distribution of Accident Severity Level by Year')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='Accident Severity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>Insight2</h1>
# <h2>The most Frequent accident severity level is consistently "Slight" across all years. So it does not change every year; it remains "Slight" as the most frequent severity level for all years.</h2>

# %% [markdown]
# <h1>Insight3</h1>
# <h2>The "Slight" severity level is consistent so it means that most accidents tend to result in minor injuries or damages. If this were to change in the future then it means an increase in serious or fatal accidents and could signal a need for immediate intervention</h2>

# %% [markdown]
# <h3>Question:</h3>
# <h2>Are there specific dates with unusually high accident frequencies?</h2>

# %%
accidents_per_date = Accident.groupby('Accident Date').size().reset_index(name='Accident Count')
accidents_per_date
# Out:
#     Accident Date  Accident Count
# 0      2019-01-01             335
# 1      2019-01-02             370
# 2      2019-01-03             397
# 3      2019-01-04             405
# 4      2019-01-05             445
# ..            ...             ...
# 571    2022-12-08             390
# 572    2022-12-09             444
# 573    2022-12-10             412
# 574    2022-12-11             378
# 575    2022-12-12             303
#
# [576 rows x 2 columns]

# %%
average_accidents = accidents_per_date['Accident Count'].mean() # average
average_accidents
# Out:
# 460.08159722222223

# %%
total_accidents = accidents_per_date['Accident Count'].sum()
total_accidents
# Out:
# 265007

# %%
plt.pie([average_accidents, total_accidents - average_accidents], labels=['Average Accidents', 'Total Accidents - Average'], autopct='%1.1f%%')
plt.title('Average Accidents vs. Total Accidents')
plt.show()

# %% [markdown]
# <h1>Insight 4</h1>
# <h2>There are 460.08 average accidents per Day</h2>

# %%
std_accidents = accidents_per_date['Accident Count'].std() # standard deviation
std_accidents
# Out:
# 94.04653024994138

# %%
threshold = average_accidents + 2 * std_accidents 
threshold

#any Day with more than approximately of the threshold is considered unusually high
# Out:
# 648.1746577221049

# %%
unusual_dates = accidents_per_date[accidents_per_date['Accident Count'] > threshold]
unusual_dates
# Out:
#     Accident Date  Accident Count
# 12     2019-02-01             676
# 13     2019-02-02             652
# 112    2019-10-05             657
# 137    2019-12-06             678
# 142    2019-12-11             653
# 143    2019-12-12             655
# 310    2021-02-11             685
# 401    2021-10-06             680
# 419    2021-11-12             659
# 423    2021-12-04             667
# 540    2022-10-01             656

# %%
# Set 'Accident Date' as the index
unusual_dates.set_index('Accident Date', inplace=True)

# %%
unusual_dates.plot(kind='bar')
plt.title('Distribution of dates with unusually high accident frequencies')
plt.xlabel('Date')
plt.ylabel('accident count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensure labels fit within the figure area
plt.show()

# %% [markdown]
# <h1>Insight 5</h1>
# <h2> The specific dates with unusually high accident frequencies are listed above from 2019 to 2022 </h2>

# %% [markdown]
# <h3>Counting the accidents happen from the weather conditions</h3>

# %%
weather_counts = Accident['Weather_Conditions'].value_counts()
weather_counts
# Out:
# Weather_Conditions
# Fine no high winds       520885
# Raining no high winds     79696
# Other                     17150
# unaccounted               14128
# Raining + high winds       9615
# Fine + high winds          8554
# Snowing no high winds      6238
# Fog or mist                3528
# Snowing + high winds        885
# Name: count, dtype: int64

# %%
weather_counts.plot(kind='bar')
plt.xticks(rotation=45)  
plt.tight_layout()  
plt.show()

# %% [markdown]
# <h1>Insight 6</h1>
# <h2> most accident happens during fine no high winds of weather conditions meaning except for fine and no high winds theres another factor affecting the accidents happen, and not depending on other weather conditions. But Understanding this factor can help people to inform and may reduce accident rates in the future.</h2>

# %% [markdown]
# <h3>Counting the accidents happen from the Light conditions</h3>

# %%
light_counts = Accident['Light_Conditions'].value_counts()
light_counts
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %%
light_counts.plot(kind='bar')
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

# %% [markdown]
# <h1>Insight 7</h1>
# <h2> most accident happens during Daylight. And understanding this factor can help people to inform and may reduce accident by addressing some factors or issues during Daylight to reduce accident rates in the future.</h2>

# %% [markdown]
# <h3>Counting the accidents happen from the Road surface conditions</h3>

# %%
road_surface_counts = Accident['Road_Surface_Conditions'].value_counts()
road_surface_counts
# Out:
# Road_Surface_Conditions
# Dry                     448547
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# Name: count, dtype: int64

# %%
road_surface_counts.plot(kind='bar')
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

# %% [markdown]
# <h1>Insight 8</h1>
# <h2> most accident happens when the Road surface is Dry which means that except for the Daylight there can be another factor like environmental factors affecting why the accident happens. But Understanding this factor can help people to inform and may reduce accident rates in the future.</h2>

# %%
Accident['District Area']
# Out:
# 0         Kensington and Chelsea
# 1         Kensington and Chelsea
# 2         Kensington and Chelsea
# 3         Kensington and Chelsea
# 4         Kensington and Chelsea
#                    ...
# 660674                  Highland
# 660675                  Highland
# 660676                  Highland
# 660677                  Highland
# 660678                  Highland
# Name: District Area, Length: 660679, dtype: category
# Categories (422, object): ['Aberdeen City', 'Aberdeenshire', 'Adur', 'Allerdale', ..., 'Wycombe', 'Wyre', 'Wyre Forest', 'York']

# %% [markdown]
# <h3>Question:</h3>
# <h2>What District Area does the accident is more likely to happen?</h2>

# %%
Distcount = Accident['District Area'].value_counts()
Distcount
# Out:
# District Area
# Birmingham            13491
# Leeds                  8898
# Manchester             6720
# Bradford               6212
# Sheffield              5710
#                       ...
# Berwick-upon-Tweed      153
# Teesdale                142
# Shetland Islands        133
# Orkney Islands          117
# Clackmannanshire         91
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# <h1>Insight 9</h1>
# <h2>The accident is more likely to happen in the Birmingham Area</h2>

# %%
Accident.describe()
# Out:
#                        Accident Date       Latitude      Longitude  \
# count                         265007  660679.000000  660679.000000
# mean   2020-11-23 16:22:04.873683456      52.553862      -1.431193
# min              2019-01-01 00:00:00      49.914430      -7.516225
# 25%              2019-12-03 00:00:00      51.490696      -2.332191
# 50%              2020-11-07 00:00:00      52.315755      -1.411613
# 75%              2021-11-07 00:00:00      53.453444      -0.232901
# max              2022-12-12 00:00:00      60.757544       1.762010
# std                              NaN       1.406896       1.383305
#
#        Number_of_Casualties  Number_of_Vehicles           Year          Month  \
# count         660679.000000       660679.000000  265007.000000  265007.000000
# mean               1.357040            1.831255    2020.407216       6.708374
# min                1.000000            1.000000    2019.000000       1.000000
# 25%                1.000000            1.000000    2019.000000       4.000000
# 50%                1.000000            2.000000    2020.000000       7.000000
# 75%                1.000000            2.000000    2021.000000      10.000000
# max               68.000000           32.000000    2022.000000      12.000000
# std                0.824847            0.715269       1.101126       3.445617
#
#                  Day      DayOfWeek
# count  265007.000000  265007.000000
# mean        6.522028       3.106367
# min         1.000000       0.000000
# 25%         4.000000       1.000000
# 50%         7.000000       3.000000
# 75%        10.000000       5.000000
# max        12.000000       6.000000
# std         3.467063       1.920114

# %% [markdown]
# <h3>Question:</h3>
# <h2>Is there a correlation between the latitude and the location of the most prone accident, Birmingham?</h2>

# %%
birmingham_data = Accident[Accident['District Area'] == 'Birmingham']
birmingham_data
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 68519   200720D003001            Slight    2019-01-02  52.513668
# 68520   200720D003101            Slight    2019-01-02  52.502396
# 68521   200720D003802           Serious    2019-01-03  52.563201
# 68522   200720D005801            Slight    2019-01-02  52.493431
# 68523   200720D005901            Slight    2019-01-05  52.510805
# ...               ...               ...           ...        ...
# 583759  201020Z500110            Slight           NaT  52.506095
# 583760  201020Z500120            Slight           NaT  52.514554
# 583761  201020Z500140            Slight           NaT  52.507630
# 583766  201020Z620211            Slight           NaT  52.509143
# 583768  201020Z679611            Slight           NaT  52.496214
#
#              Light_Conditions District Area  Longitude  Number_of_Casualties  \
# 68519   Darkness - lights lit    Birmingham  -1.901975                     1
# 68520                Daylight    Birmingham  -1.867086                     1
# 68521                Daylight    Birmingham  -1.822793                     1
# 68522                Daylight    Birmingham  -1.818507                     1
# 68523   Darkness - lights lit    Birmingham  -1.834202                     1
# ...                       ...           ...        ...                   ...
# 583759  Darkness - lights lit    Birmingham  -1.878861                     1
# 583760  Darkness - lights lit    Birmingham  -1.765076                     1
# 583761  Darkness - lights lit    Birmingham  -1.814913                     2
# 583766  Darkness - lights lit    Birmingham  -1.871043                     2
# 583768               Daylight    Birmingham  -1.886989                     2
#
#         Number_of_Vehicles Road_Surface_Conditions           Road_Type  \
# 68519                    2             Wet or damp    Dual carriageway
# 68520                    2             Wet or damp  Single carriageway
# 68521                    1                     Dry  Single carriageway
# 68522                    2             Wet or damp    Dual carriageway
# 68523                    3                     Dry    Dual carriageway
# ...                    ...                     ...                 ...
# 583759                   2                    Snow  Single carriageway
# 583760                   2            Frost or ice    Dual carriageway
# 583761                   2             Wet or damp    Dual carriageway
# 583766                   2             Wet or damp    Dual carriageway
# 583768                   2                     Dry    Dual carriageway
#
#        Urban_or_Rural_Area     Weather_Conditions           Vehicle_Type  \
# 68519                Urban  Raining no high winds                    Car
# 68520                Urban  Raining no high winds                    Car
# 68521                Urban     Fine no high winds                    Car
# 68522                Urban            unaccounted                    Car
# 68523                Urban     Fine no high winds                    Car
# ...                    ...                    ...                    ...
# 583759               Urban  Snowing no high winds                    Car
# 583760               Rural  Snowing no high winds                    Car
# 583761               Urban  Raining no high winds                    Car
# 583766               Urban     Fine no high winds  Taxi/Private hire car
# 583768               Urban     Fine no high winds                    Car
#
#           Year  Month  Day  DayOfWeek
# 68519   2019.0    1.0  2.0        2.0
# 68520   2019.0    1.0  2.0        2.0
# 68521   2019.0    1.0  3.0        3.0
# 68522   2019.0    1.0  2.0        2.0
# 68523   2019.0    1.0  5.0        5.0
# ...        ...    ...  ...        ...
# 583759     NaN    NaN  NaN        NaN
# 583760     NaN    NaN  NaN        NaN
# 583761     NaN    NaN  NaN        NaN
# 583766     NaN    NaN  NaN        NaN
# 583768     NaN    NaN  NaN        NaN
#
# [13491 rows x 18 columns]

# %%
accident_counts = birmingham_data.groupby('Latitude').size()
accident_counts
# Out:
# Latitude
# 52.384250    1
# 52.384969    1
# 52.385149    4
# 52.385598    1
# 52.385867    1
#             ..
# 52.599106    1
# 52.601288    1
# 52.602609    1
# 52.606644    1
# 52.607004    1
# Length: 8844, dtype: int64

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(accident_counts.index, accident_counts.values, s=5, alpha=0.5)
plt.title('Accidents by Latitude in Birmingham')
plt.xlabel('Latitude')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# <h1>Insight 10</h1>
# <h2>The fact that there are multiple accidents (4 in this case) at the same latitude suggests that this location could be a hotspot for accidents</h2>

# %%
# Filter data for accidents at the specified latitude
latitude_filter = 52.385149
latitudefltrd = Accident[Accident['Latitude'] == latitude_filter]
latitudefltrd
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 70343   200720E065801           Serious           NaT  52.385149
# 70770   200720E132901            Slight    2019-10-03  52.385149
# 249563  200820E047701            Slight           NaT  52.385149
# 582202  201020S053310            Slight    2022-12-10  52.385149
#
#              Light_Conditions District Area  Longitude  Number_of_Casualties  \
# 70343                Daylight    Birmingham  -2.001877                     1
# 70770                Daylight    Birmingham  -2.001877                     2
# 249563  Darkness - lights lit    Birmingham  -2.001877                     1
# 582202  Darkness - lights lit    Birmingham  -2.001877                     1
#
#         Number_of_Vehicles Road_Surface_Conditions           Road_Type  \
# 70343                    2                     Dry    Dual carriageway
# 70770                    2             Wet or damp    Dual carriageway
# 249563                   2             Wet or damp  Single carriageway
# 582202                   2             Wet or damp    Dual carriageway
#
#        Urban_or_Rural_Area     Weather_Conditions  \
# 70343                Urban     Fine no high winds
# 70770                Urban  Raining no high winds
# 249563               Urban  Raining no high winds
# 582202               Urban                  Other
#
#                            Vehicle_Type    Year  Month   Day  DayOfWeek
# 70343   Goods over 3.5t. and under 7.5t     NaN    NaN   NaN        NaN
# 70770                               Car  2019.0   10.0   3.0        3.0
# 249563    Goods 7.5 tonnes mgw and over     NaN    NaN   NaN        NaN
# 582202                              Car  2022.0   12.0  10.0        5.0

# %%
# Groupby road type and road condition to analyze accident counts
road_type_condition = latitudefltrd.groupby(['Road_Type', 'Road_Surface_Conditions']).size()
road_type_condition
# Out:
# Road_Type           Road_Surface_Conditions
# Dual carriageway    Dry                        1
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                2
# One way street      Dry                        0
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                0
# Roundabout          Dry                        0
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                0
# Single carriageway  Dry                        0
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                1
# Slip road           Dry                        0
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                0
# unknown             Dry                        0
#                     Flood over 3cm. deep       0
#                     Frost or ice               0
#                     Snow                       0
#                     Wet or damp                0
# dtype: int64

# %%
# Unstack the series to create a DataFrame
road_type_condition_df = road_type_condition.unstack()
road_type_condition_df
# Out:
# Road_Surface_Conditions  Dry  Flood over 3cm. deep  Frost or ice  Snow  \
# Road_Type
# Dual carriageway           1                     0             0     0
# One way street             0                     0             0     0
# Roundabout                 0                     0             0     0
# Single carriageway         0                     0             0     0
# Slip road                  0                     0             0     0
# unknown                    0                     0             0     0
#
# Road_Surface_Conditions  Wet or damp
# Road_Type
# Dual carriageway                   2
# One way street                     0
# Roundabout                         0
# Single carriageway                 1
# Slip road                          0
# unknown                            0

# %%
# Fill missing values with 0 (if any)
road_type_condition_df = road_type_condition_df.fillna(0)
road_type_condition_df
# Out:
# Road_Surface_Conditions  Dry  Flood over 3cm. deep  Frost or ice  Snow  \
# Road_Type
# Dual carriageway           1                     0             0     0
# One way street             0                     0             0     0
# Roundabout                 0                     0             0     0
# Single carriageway         0                     0             0     0
# Slip road                  0                     0             0     0
# unknown                    0                     0             0     0
#
# Road_Surface_Conditions  Wet or damp
# Road_Type
# Dual carriageway                   2
# One way street                     0
# Roundabout                         0
# Single carriageway                 1
# Slip road                          0
# unknown                            0

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(road_type_condition_df, annot=True, cmap='Blues', fmt='g')
plt.title('Accidents by Road Type and Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Road Type')
plt.show()

# %%
result = road_type_condition.reset_index(name='Accident_Count')
result
# Out:
#              Road_Type Road_Surface_Conditions  Accident_Count
# 0     Dual carriageway                     Dry               1
# 1     Dual carriageway    Flood over 3cm. deep               0
# 2     Dual carriageway            Frost or ice               0
# 3     Dual carriageway                    Snow               0
# 4     Dual carriageway             Wet or damp               2
# 5       One way street                     Dry               0
# 6       One way street    Flood over 3cm. deep               0
# 7       One way street            Frost or ice               0
# 8       One way street                    Snow               0
# 9       One way street             Wet or damp               0
# 10          Roundabout                     Dry               0
# 11          Roundabout    Flood over 3cm. deep               0
# 12          Roundabout            Frost or ice               0
# 13          Roundabout                    Snow               0
# 14          Roundabout             Wet or damp               0
# 15  Single carriageway                     Dry               0
# 16  Single carriageway    Flood over 3cm. deep               0
# 17  Single carriageway            Frost or ice               0
# 18  Single carriageway                    Snow               0
# 19  Single carriageway             Wet or damp               1
# 20           Slip road                     Dry               0
# 21           Slip road    Flood over 3cm. deep               0
# 22           Slip road            Frost or ice               0
# 23           Slip road                    Snow               0
# 24           Slip road             Wet or damp               0
# 25             unknown                     Dry               0
# 26             unknown    Flood over 3cm. deep               0
# 27             unknown            Frost or ice               0
# 28             unknown                    Snow               0
# 29             unknown             Wet or damp               0

# %% [markdown]
# <h1>Insight 11</h1>
# <h2>The analysis supports the idea that latitude 52.385149 could be a hotspot for accidents, particularly due to the influence of road surface conditions (wet or damp)</h2>

# %% [markdown]
# <h3>Question:</h3>
# <h1>To analyze the temporal patterns of accidents at latitude 52.385149. Are there any trends  in when accidents occur?</h1>

# %%
accidents_per_day = latitudefltrd.groupby('Day').size()
accidents_per_day
# Out:
# Day
# 3.0     1
# 10.0    1
# dtype: int64

# %%
accidents_per_day.plot(kind='bar', figsize=(6, 4), color='blue')
plt.title('Accidents per Day')
plt.xlabel('Day of the Month')
plt.ylabel('Number of Accidents')
plt.xticks([0, 1], ['3rd', '10th'])  # Correctly label the x-axis
plt.show()

# %% [markdown]
# <h1>Insight 12</h1>
# <h2>I found out that Accidents occurred on only two specific days of the month: the 3rd and the 10th. This limited distribution suggests that accidents at this latitude do not occur frequently throughout the month.</h2>

# %%
accidents_per_day_of_week = latitudefltrd.groupby('DayOfWeek').size()
accidents_per_day_of_week
# Out:
# DayOfWeek
# 3.0    1
# 5.0    1
# dtype: int64

# %%
accidents_per_day_of_week.plot(kind='bar', figsize=(6, 4), color='blue')
plt.title('Accidents by Day of the Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Accidents')
plt.xticks([0, 1], ['3rd', '5th'])  # Correctly label the x-axis
plt.show()

# %% [markdown]
# <h1>Insight 13</h1>
# <h2>I found out that accidents were recorded on two days of the week: Wednesday (Day 3) and Friday (Day 5). This indicates that accidents may be more likely to occur mid-week and at the end of the workweek.</h2>

# %%
accidents_per_month = latitudefltrd.groupby('Month').size()
accidents_per_month
# Out:
# Month
# 10.0    1
# 12.0    1
# dtype: int64

# %%
accidents_per_month.plot(kind='bar', figsize=(6, 4), color='blue')
plt.title('Accidents per Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.xticks([0, 1], ['10th', '12th'])  # Correctly label the x-axis
plt.show()

# %% [markdown]
# <h1>Insight 14</h1>
# <h2>I found out that accidents occurred in two months: October (Month 10) and December (Month 12). This indicates potential seasonal influences, where there might be more accidents in certain months.</h2>

# %%
accidents_per_year = latitudefltrd.groupby('Year').size()
accidents_per_year
# Out:
# Year
# 2019.0    1
# 2022.0    1
# dtype: int64

# %%
accidents_per_day_of_week.plot(kind='bar', figsize=(6, 4), color='blue')
plt.title('Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.xticks([0, 1], ['2019', '2022'])  # Correctly label the x-axis
plt.show()

# %% [markdown]
# <h1>Insight 15</h1>
# <h2>I found out that accidents were recorded in two different years: 2019 and 2022. This suggests that while accidents do occur, they may not be a consistent or frequent issue over time at this specific latitude.
# </h2>

# %% [markdown]
# <h3>Question: </h3>
# <h1>What is the severity of the accidents occured in the Latitude52.385149</h1>

# %%
severity_counts = latitudefltrd.groupby('Accident_Severity').size()
severity_counts
# Out:
# Accident_Severity
# Fatal      0
# Serious    1
# Slight     3
# dtype: int64

# %%
severity_counts.plot(kind='bar', figsize=(6, 4), color='blue')
plt.title('Severity of the accidents occured in the Latitude52.385149')
plt.xlabel('Severity')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# <h1>Insight 16</h1>
# <h2>At latitude 52.385149, the analysis of accident severity reveals no fatal accidents, one serious accident, and three slight accidents. This indicates that while accidents do occur in this area, they are generally not severe. </h2>

# %% [markdown]
# <h3>continuation..</h3>

# %%
correlation = birmingham_data['Latitude'].corr(birmingham_data['Number_of_Casualties'])
print(f"Correlation between Latitude and Number of Casualties: {correlation}")
# Out:
# Correlation between Latitude and Number of Casualties: 0.008788440104652023

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(birmingham_data['Latitude'], birmingham_data['Number_of_Casualties'])
plt.title('Relationship between Latitude and Number of Casualties')
plt.xlabel('Latitude')
plt.ylabel('Number of Casualties')
plt.show()

# %% [markdown]
# <h1>Insight 17</h1>
# <h2>The correlation between latitude and the number of casualties in Birmingham is approximately 0.0088, indicating no significant relationship between these variables.</h2>

# %% [markdown]
# <h3>Confirming if the Birmingham is Urban or Rural</h3>

# %%
Accident[['District Area', 'Urban_or_Rural_Area']].value_counts()
# Out:
# District Area       Urban_or_Rural_Area
# Birmingham          Urban                  13357
# Leeds               Urban                   7124
# Manchester          Urban                   6577
# Westminster         Urban                   5706
# Liverpool           Urban                   5539
#                                            ...
# Portsmouth          Unallocated                1
# Edinburgh, City of  Unallocated                1
# Newham              Rural                      1
# Preston             Unallocated                1
# Isle of Anglesey    Unallocated                1
# Name: count, Length: 824, dtype: int64

# %% [markdown]
# <h1>Insight 18</h1>
# <h2>Birmingham, as a densely populated urban area, experiences accident frequency influenced more by factors like traffic volume, road conditions, and driver behavior than geographic factors like latitude. My analysis shows that accidents are more prevalent in Birmingham, particularly under wet or damp conditions, emphasizing the need to address urban traffic dynamics and environmental factors to improve road safety</h2>

# %% [markdown]
# <h3>Question: </h3>
# <h2>How does the vehicle type involved correlate with the severity of accidents? Are certain vehicle types more prone to severe accidents?</h2>

# %%
Accident['Vehicle_Type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                          Car
# 1                                          Car
# 2                        Taxi/Private hire car
# 3         Bus or coach (17 or more pass seats)
# 4                                Other vehicle
#                           ...
# 660674                                     Car
# 660675                                     Car
# 660676                                     Car
# 660677                   Motorcycle over 500cc
# 660678                                     Car
# Name: Vehicle_Type, Length: 660679, dtype: category
# Categories (16, object): ['Agricultural vehicle', 'Bus or coach (17 or more pass seats)', 'Car', 'Data missing or out of range', ..., 'Pedal cycle', 'Ridden horse', 'Taxi/Private hire car', 'Van / Goods 3.5 tonnes mgw or under']>

# %%
filtered_data = Accident[(Accident['Vehicle_Type'] != 'Data missing or out of range') & 
                   (Accident['Accident_Severity'].notnull())]

filtered_data
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious           NaT  51.517715
# 3       200701BS66128           Serious           NaT  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight           NaT  57.374005
# 660675  201091NM01881            Slight           NaT  57.232273
# 660676  201091NM01935            Slight           NaT  57.585044
# 660677  201091NM01964           Serious           NaT  57.214898
# 660678  201091NM02142           Serious           NaT  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                  unknown               Urban            unaccounted
# 3       Single carriageway               Urban     Fine no high winds
# 4                  unknown               Urban            unaccounted
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type    Year  Month  Day  DayOfWeek
# 0                                        Car  2019.0    6.0  5.0        2.0
# 1                                        Car  2019.0    7.0  2.0        1.0
# 2                      Taxi/Private hire car     NaN    NaN  NaN        NaN
# 3       Bus or coach (17 or more pass seats)     NaN    NaN  NaN        NaN
# 4                              Other vehicle  2019.0    9.0  3.0        1.0
# ...                                      ...     ...    ...  ...        ...
# 660674                                   Car     NaN    NaN  NaN        NaN
# 660675                                   Car     NaN    NaN  NaN        NaN
# 660676                                   Car     NaN    NaN  NaN        NaN
# 660677                 Motorcycle over 500cc     NaN    NaN  NaN        NaN
# 660678                                   Car     NaN    NaN  NaN        NaN
#
# [660673 rows x 18 columns]

# %%
severity_by_vehicle = filtered_data.groupby(['Vehicle_Type', 'Accident_Severity']).size()
severity_by_vehicle
# Out:
# Vehicle_Type                           Accident_Severity
# Agricultural vehicle                   Fatal                    21
#                                        Serious                 282
#                                        Slight                 1644
# Bus or coach (17 or more pass seats)   Fatal                   325
#                                        Serious                3373
#                                        Slight                22180
# Car                                    Fatal                  6577
#                                        Serious               66461
#                                        Slight               424954
# Data missing or out of range           Fatal                     0
#                                        Serious                   0
#                                        Slight                    0
# Goods 7.5 tonnes mgw and over          Fatal                   216
#                                        Serious                2321
#                                        Slight                14770
# Goods over 3.5t. and under 7.5t        Fatal                    67
#                                        Serious                 857
#                                        Slight                 5172
# Minibus (8 - 16 passenger seats)       Fatal                    29
#                                        Serious                 276
#                                        Slight                 1671
# Motorcycle 125cc and under             Fatal                   189
#                                        Serious                2031
#                                        Slight                13049
# Motorcycle 50cc and under              Fatal                    95
#                                        Serious                1014
#                                        Slight                 6494
# Motorcycle over 125cc and up to 500cc  Fatal                   105
#                                        Serious                1014
#                                        Slight                 6537
# Motorcycle over 500cc                  Fatal                   339
#                                        Serious                3457
#                                        Slight                21861
# Other vehicle                          Fatal                    70
#                                        Serious                 767
#                                        Slight                 4800
# Pedal cycle                            Fatal                     6
#                                        Serious                  39
#                                        Slight                  152
# Ridden horse                           Fatal                     0
#                                        Serious                   0
#                                        Slight                    4
# Taxi/Private hire car                  Fatal                   155
#                                        Serious                1771
#                                        Slight                11368
# Van / Goods 3.5 tonnes mgw or under    Fatal                   467
#                                        Serious                4554
#                                        Slight                29139
# dtype: int64

# %%
severity_analysis = severity_by_vehicle.reset_index(name='Accident_Count')
severity_analysis
# Out:
#                              Vehicle_Type Accident_Severity  Accident_Count
# 0                    Agricultural vehicle             Fatal              21
# 1                    Agricultural vehicle           Serious             282
# 2                    Agricultural vehicle            Slight            1644
# 3    Bus or coach (17 or more pass seats)             Fatal             325
# 4    Bus or coach (17 or more pass seats)           Serious            3373
# 5    Bus or coach (17 or more pass seats)            Slight           22180
# 6                                     Car             Fatal            6577
# 7                                     Car           Serious           66461
# 8                                     Car            Slight          424954
# 9            Data missing or out of range             Fatal               0
# 10           Data missing or out of range           Serious               0
# 11           Data missing or out of range            Slight               0
# 12          Goods 7.5 tonnes mgw and over             Fatal             216
# 13          Goods 7.5 tonnes mgw and over           Serious            2321
# 14          Goods 7.5 tonnes mgw and over            Slight           14770
# 15        Goods over 3.5t. and under 7.5t             Fatal              67
# 16        Goods over 3.5t. and under 7.5t           Serious             857
# 17        Goods over 3.5t. and under 7.5t            Slight            5172
# 18       Minibus (8 - 16 passenger seats)             Fatal              29
# 19       Minibus (8 - 16 passenger seats)           Serious             276
# 20       Minibus (8 - 16 passenger seats)            Slight            1671
# 21             Motorcycle 125cc and under             Fatal             189
# 22             Motorcycle 125cc and under           Serious            2031
# 23             Motorcycle 125cc and under            Slight           13049
# 24              Motorcycle 50cc and under             Fatal              95
# 25              Motorcycle 50cc and under           Serious            1014
# 26              Motorcycle 50cc and under            Slight            6494
# 27  Motorcycle over 125cc and up to 500cc             Fatal             105
# 28  Motorcycle over 125cc and up to 500cc           Serious            1014
# 29  Motorcycle over 125cc and up to 500cc            Slight            6537
# 30                  Motorcycle over 500cc             Fatal             339
# 31                  Motorcycle over 500cc           Serious            3457
# 32                  Motorcycle over 500cc            Slight           21861
# 33                          Other vehicle             Fatal              70
# 34                          Other vehicle           Serious             767
# 35                          Other vehicle            Slight            4800
# 36                            Pedal cycle             Fatal               6
# 37                            Pedal cycle           Serious              39
# 38                            Pedal cycle            Slight             152
# 39                           Ridden horse             Fatal               0
# 40                           Ridden horse           Serious               0
# 41                           Ridden horse            Slight               4
# 42                  Taxi/Private hire car             Fatal             155
# 43                  Taxi/Private hire car           Serious            1771
# 44                  Taxi/Private hire car            Slight           11368
# 45    Van / Goods 3.5 tonnes mgw or under             Fatal             467
# 46    Van / Goods 3.5 tonnes mgw or under           Serious            4554
# 47    Van / Goods 3.5 tonnes mgw or under            Slight           29139

# %%
severity_pivot = severity_analysis.pivot(index='Vehicle_Type', columns='Accident_Severity', values='Accident_Count').fillna(0) 
severity_pivot
# Out:
# Accident_Severity                      Fatal  Serious  Slight
# Vehicle_Type
# Agricultural vehicle                      21      282    1644
# Bus or coach (17 or more pass seats)     325     3373   22180
# Car                                     6577    66461  424954
# Data missing or out of range               0        0       0
# Goods 7.5 tonnes mgw and over            216     2321   14770
# Goods over 3.5t. and under 7.5t           67      857    5172
# Minibus (8 - 16 passenger seats)          29      276    1671
# Motorcycle 125cc and under               189     2031   13049
# Motorcycle 50cc and under                 95     1014    6494
# Motorcycle over 125cc and up to 500cc    105     1014    6537
# Motorcycle over 500cc                    339     3457   21861
# Other vehicle                             70      767    4800
# Pedal cycle                                6       39     152
# Ridden horse                               0        0       4
# Taxi/Private hire car                    155     1771   11368
# Van / Goods 3.5 tonnes mgw or under      467     4554   29139

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(severity_pivot, annot=True, cmap='Blues', fmt='g')
plt.title('Accidents by Vehicle Type and Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Vehicle Type')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensure labels fit within the figure area
plt.show()

# %%
severity_pivot['Total_Accidents'] = severity_pivot.sum(axis=1)
severity_pivot
# Out:
# Accident_Severity                      Fatal  Serious  Slight  Total_Accidents
# Vehicle_Type
# Agricultural vehicle                      21      282    1644             1947
# Bus or coach (17 or more pass seats)     325     3373   22180            25878
# Car                                     6577    66461  424954           497992
# Data missing or out of range               0        0       0                0
# Goods 7.5 tonnes mgw and over            216     2321   14770            17307
# Goods over 3.5t. and under 7.5t           67      857    5172             6096
# Minibus (8 - 16 passenger seats)          29      276    1671             1976
# Motorcycle 125cc and under               189     2031   13049            15269
# Motorcycle 50cc and under                 95     1014    6494             7603
# Motorcycle over 125cc and up to 500cc    105     1014    6537             7656
# Motorcycle over 500cc                    339     3457   21861            25657
# Other vehicle                             70      767    4800             5637
# Pedal cycle                                6       39     152              197
# Ridden horse                               0        0       4                4
# Taxi/Private hire car                    155     1771   11368            13294
# Van / Goods 3.5 tonnes mgw or under      467     4554   29139            34160

# %%
severity_pivot['Severe_Accidents'] = severity_pivot.get('Serious', 0) + severity_pivot.get('Fatal', 0)
severity_pivot['Severe_Proportion'] = severity_pivot['Severe_Accidents'] / severity_pivot['Total_Accidents']

# %%
severity_pivot['Severe_Accidents']
# Out:
# Vehicle_Type
# Agricultural vehicle                       303
# Bus or coach (17 or more pass seats)      3698
# Car                                      73038
# Data missing or out of range                 0
# Goods 7.5 tonnes mgw and over             2537
# Goods over 3.5t. and under 7.5t            924
# Minibus (8 - 16 passenger seats)           305
# Motorcycle 125cc and under                2220
# Motorcycle 50cc and under                 1109
# Motorcycle over 125cc and up to 500cc     1119
# Motorcycle over 500cc                     3796
# Other vehicle                              837
# Pedal cycle                                 45
# Ridden horse                                 0
# Taxi/Private hire car                     1926
# Van / Goods 3.5 tonnes mgw or under       5021
# Name: Severe_Accidents, dtype: int64

# %%
severity_pivot['Severe_Accidents'].plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('Severe Accidents by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Severe Accidents')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.pie(severity_pivot['Severe_Accidents'], labels=severity_pivot.index, autopct='%1.1f%%')
plt.title('Distribution of Severe Accidents by Vehicle Type')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# <h1>Insight 19</h1>
# <h2>The analysis of severe accidents reveals that the Car category has the highest number of severe accidents, totaling 73,038, followed by Bus or coach (17 or more passenger seats) with 3,698 and Van / Goods 3.5 tonnes mgw or under with 5,021. </h2>

# %%
severity_pivot['Severe_Proportion']
# Out:
# Vehicle_Type
# Agricultural vehicle                     0.155624
# Bus or coach (17 or more pass seats)     0.142901
# Car                                      0.146665
# Data missing or out of range                  NaN
# Goods 7.5 tonnes mgw and over            0.146588
# Goods over 3.5t. and under 7.5t          0.151575
# Minibus (8 - 16 passenger seats)         0.154352
# Motorcycle 125cc and under               0.145393
# Motorcycle 50cc and under                0.145863
# Motorcycle over 125cc and up to 500cc    0.146160
# Motorcycle over 500cc                    0.147952
# Other vehicle                            0.148483
# Pedal cycle                              0.228426
# Ridden horse                             0.000000
# Taxi/Private hire car                    0.144877
# Van / Goods 3.5 tonnes mgw or under      0.146985
# Name: Severe_Proportion, dtype: float64

# %%
# Plotting the horizontal bar chart
severity_pivot['Severe_Proportion'].plot(kind='barh', figsize=(8, 10), color='blue')
plt.title('Proportion of Severe Accidents by Vehicle Type')
plt.xlabel('Proportion of Severe Accidents')
plt.ylabel('Vehicle Type')
plt.show()

# %% [markdown]
# <h1>Insight 20</h1>
# <h2>The Pedal cycle category stands out with the highest proportion of severe accidents at approximately 11.42%, indicating that cyclists may face a higher risk of severe outcomes in accidents compared to other vehicle types. Conversely, the proportion of severe accidents for vehicles like Agricultural vehicles, Buses, and Cars ranges from about 7.14% to 7.78%, suggesting that while these vehicles are involved in many accidents, the severity is not disproportionately high relative to their accident counts.</h2>

# %% [markdown]
# <h3>Question:</h3>
# <h1>How does the number of accidents vary by month?</h1>

# %%
# Create a dictionary mapping month numbers to month names
month_dict = {
    1.0: 'January',
    2.0: 'February',
    3.0: 'March',
    4.0: 'April',
    5.0: 'May',
    6.0: 'June',
    7.0: 'July',
    8.0: 'August',
    9.0: 'September',
    10.0: 'October',
    11.0: 'November',
    12.0: 'December'
}

# Use the dictionary to convert month numbers to names
accidents_per_month = Accident.groupby('Month').size()

# Convert month numbers to names
accidents_per_month_named = accidents_per_month.rename(index=month_dict)

accidents_per_month_named
# Out:
# Month
# January      18252
# February     22264
# March        21824
# April        19787
# May          21723
# June         22196
# July         22939
# August       21106
# September    22558
# October      23962
# November     24240
# December     24156
# dtype: int64

# %%
accidents_per_month = Accident.groupby('Month').size().reset_index(name='Counts')
accidents_per_month
# Out:
#     Month  Counts
# 0     1.0   18252
# 1     2.0   22264
# 2     3.0   21824
# 3     4.0   19787
# 4     5.0   21723
# 5     6.0   22196
# 6     7.0   22939
# 7     8.0   21106
# 8     9.0   22558
# 9    10.0   23962
# 10   11.0   24240
# 11   12.0   24156

# %%
plt.figure(figsize=(10, 6))
plt.plot(accidents_per_month['Month'], accidents_per_month['Counts'], marker='o')
plt.title('Accidents per Month')
plt.xlabel('Months')
plt.ylabel('Counts of Accidents')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensure labels fit within the figure area
plt.show()

# %% [markdown]
# <h1>Insight 21</h1>
# <h2>Accidents occur most frequently in the months of November and December, with October also being a peak month, suggesting a seasonal increase in accident rates during these periods.</h2>
